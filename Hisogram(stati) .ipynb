# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the iris dataset
from sklearn.datasets import load_iris
iris=load_iris()
iris_df=pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# This data sets cinsists of 3 different types of iris flowers(setosa, Versicolour, and virginica) petal and sepal length.

# %% [markdown]
# # **Histogram**

# %%
plt.hist(iris_df["sepal length (cm)"],color="lightgreen",edgecolor="black")
plt.title("Histogram of sepal length (cm)")
# Out:
# Text(0.5, 1.0, 'Histogram of sepal length (cm)')

# %%
plt.hist(iris_df["sepal width (cm)"], color="lightblue",edgecolor="black")
plt.title("sepal width (cm)")
# Out:
# Text(0.5, 1.0, 'sepal width (cm)')

# %%
#Distribution
sns.histplot(iris_df["sepal width (cm)"],kde=True)
plt.title("sepal width (cm) (line graph)")
# Out:
# Text(0.5, 1.0, 'sepal width (cm) (line graph)')

# %%
# Plotting histograms for each feature
iris_df.hist(edgecolor="black")
plt.suptitle("Histograms of iris Dataset Features",fontsize=16) # suptitle(supertitle)
plt.show()

# %% [markdown]
# Here are some inferences that can be drawn from the histograms for the Iris dataset:
#
# ### **1. Sepal Length**:
# - The data appears to be somewhat normally distributed, but with a slight right skew. The majority of the values are clustered between 5 and 6 cm.
#
#
# ### **2. Sepal Width**:
# - The distribution is not normal; it has two prominent peaks, indicating a **bimodal distribution**. The data points are spread more broadly, ranging from 2 cm to 4 cm.
#
#
# ### **3. Petal Length**:
# - This feature shows a **strong right-skew**. The majority of the data points are concentrated on the lower end (around 1 to 2 cm), with fewer data points in the higher range.
#
#
# ### **4. Petal Width**:
# - Similar to petal length, the distribution is **right-skewed**, with most values clustered between 0.1 cm and 0.6 cm.
#
#
# ### **Overall Insights**:
# - **Skewness**: Both petal length and petal width are right-skewed, indicating that most Iris flowers in the dataset have shorter petals.
# - **Bimodal distribution**: Sepal width has a bimodal distribution, which might indicate that different species of Iris exhibit different sepal widths.

# %% [markdown]
# # **Assignment**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# load the iris dataset
from sklearn.datasets import load_wine
wine=load_wine()
df=pd.DataFrame(wine.data, columns=wine.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df.hist(edgecolor="black",figsize=(15,10))
plt.suptitle("Histogram of wine data features ",fontsize=25) # suptitle(supertitle)
plt.show()

# %% [markdown]
# * Alcohol
#   * The data appears to be somewhat normally distributed, but with a slight left skew.
#
# * Malic acid
#   * the data appears to be highly skewed towards right
#
# * ash
#   * The data appears to be somewhat normally distributed.
#
# * alcalinity_of_ash
#   * The data appears to be somewhat normally distributed
#
# * magnesium
#   * Bimodal distribution with 2 peak values
#
# * total_phenols
#   * Bimodal distribution with 2 peak point in between 2.5 and 3
#
# * flavanoids
#   * Highly right skewed , Values are concentrated on the beginning of the graph
#
# * nonflavanoid_phenols
#   * The data appears to be somewhat normally distributed, but with a right skew
#
# *	proanthocyanins
#   * The data appears to be somewhat normally distributed, but with a slight right skew
#
# *	color_intensity
#   * the data appears to be bimodal distn with skewed towards right and with two high peaks in between 2 and 6
#
# *	hue
#   * The data appears to be somewhat normally distributed, but with a slight left skew
#
# *	od280/od315_of_diluted_wines
#   * bimodal distribution
#
# *	proline
#   * High right skewed with peak values in between 500 and 750

# %% [markdown]
# **alchol**
#
# - The data appears to be somewhat normally distributed, but with a slight left skew.
#
# **malic_acid**
#
# - This feature shows a strong right-skew. The majority of the data points are concentrated on (around 0 to 2 cm)
#
#
# **color_intensity**
#
# - the data appears to be bimodal distn with skewed towards right and with two high peaks in between 2 and 6
#
#
# **hue**
#
# - The The data appears to be somewhat normally distributed, but with a slight left skew
#
#
# **alcalinity_of_ash**
#
# - The distribution is  normal; The majority of the values are clustered between 15 and 20 cm.
#
#
# **proline**
#
# - This feature shows a strong right-skew. The majority of the data points are concentrated on 500 and 1000
#
#
# **magnesium**
#
# - The data appears to be somewhat normally distributed, but with a slight right skew. The majority of the values are clustered between 75 and 100 cm

# %% [markdown]
# **alchol**
#
# - its not normal distribution and, also its not have right skew and left skew,majority data clustered between 12 and 13.

# %%
plt.boxplot(df["alcohol"],vert=False,patch_artist=True)
plt.suptitle("alcohol")
plt.show()

# %% [markdown]
# **malic_acid**
#
# - This feature shows a strong right-skew. The majority of the data points are concentrated on (around 0 to 2 cm)

# %%
plt.boxplot(df["ash"],vert=False,patch_artist=True)
plt.suptitle("ash")
plt.show()

# %% [markdown]
# **color_intensity**
#
# - The data appears to be somewhat normally distributed, but with a slight right skew. The majority of the values are clustered between 0 and 5 cm

# %%
plt.boxplot(df["color_intensity"],vert=False,patch_artist=True)
plt.suptitle("color_intensity")
plt.show()

# %% [markdown]
# **hue**
#
# - The distribution is not normal; it has two prominent peaks, indicating a **bimodal distribution**. The data points are spread more broadly, ranging from 0.5 and 1 cm.

# %%
plt.boxplot(df["hue"],vert=False,patch_artist=True)
plt.suptitle("hue")
plt.show()

# %% [markdown]
# **alcalinity_of_ash**
#
# - The distribution is  normal; The majority of the values are clustered between 15 and 20 cm.

# %%
plt.boxplot(df["alcalinity_of_ash"],vert=False,patch_artist=True)
plt.suptitle("alcalinity_of_ash")
plt.show()

# %% [markdown]
# **proline**
#
# - This feature shows a strong right-skew. The majority of the data points are concentrated on 500 and 1000

# %%
plt.boxplot(df["proline"],vert=False,patch_artist=True)
plt.suptitle("proline")
plt.show()

# %% [markdown]
# **magnesium**
#
# - The data appears to be somewhat normally distributed, but with a slight right skew. The majority of the values are clustered between 75 and 100 cm

# %%
plt.boxplot(df["magnesium"],vert=False,patch_artist=True)
plt.suptitle("magnesium")
plt.show()

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.plot(kind="box",subplots=True, layout=(4,4), figsize=(30,20),color="blue")
plt.suptitle("Boxplots of wine Dataset Features",fontsize=30)
plt.show()

# %% [markdown]
# # **Boxplots**

# %%
print(np.quantile(iris_df["sepal length (cm)"],[0.25,0.5,0.75]))
#0.25 means Q1(25%)
# 0.5 means Q2/median(50%)
# 0.75 means Q2(75%)
# Out:
# [5.1 5.8 6.4]

# %%
plt.boxplot(iris_df["sepal length (cm)"],vert=False, patch_artist=True) # vert=(vertically varano?) artist=just coluor
plt.title("Box of sepal length")
plt.xlabel("value") # xlabel=x-axis name
# Out:
# Text(0.5, 0, 'value')

# %%
plt.boxplot(iris_df["sepal width (cm)"]) # artist=just coluor -- no artist= no coluor
plt.title("Box of sepal width")
plt.xlabel("value") # xlabel=x-axis name
# Out:
# Text(0.5, 0, 'value')

# %%
iris_df.plot(kind="box",subplots=True, layout=(1,4), figsize=(12,6),color="blue")
plt.suptitle("Boxplots of Iris Dataset Features",fontsize=16)
plt.show()

# %% [markdown]
# - **Outliers:** The boxplots reveal that there are a few outliers in the depal width. The mist of the distributions are right-skewed.The interquartile range (IQR) is narrower for Sepal Width compared to the other features.

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# The describe() function in a pandas DataFrame provides a quick overview of the statistical properties of the data.
#
# It generates descriptive statistics for each numerical column in the DataFrame including
# * Count: Number of non-null entries in each column.
# * Mean: Average value of the column.
# * Standard Deviation (std): Measure of the spread or dispersion of the values in the column.
# * Minimum (min): The smallest value in the column.
# * 25th Percentile (25%): Value below which 25% of the data falls (also known as the first quartile).
# * 50th Percentile (50%): Median value of the column, below which 50% of the data falls.
# * 75th Percentile (75%): Value below which 75% of the data falls (also known as the third quartile).
# * Maximum (max): The largest value in the column.
